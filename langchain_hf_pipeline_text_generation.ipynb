# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaan20072612/LLM-Playbook/blob/main/langchain_hf_pipeline_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nbstripout

# %%
pip install -qU --upgrade langchain langchain-community

# %%
from transformers import pipeline
pipe = pipeline("text-generation" , model = "Qwen/Qwen2.5-1.5B-Instruct" , max_length = 512)
# Out:
# Device set to use cpu

# %%
from langchain.llms import HuggingFacePipeline
chat_model = HuggingFacePipeline(pipeline = pipe)

# %%
response = chat_model.invoke("What is the meaning of Ishaan")
print(response)
# Out:
# What is the meaning of Ishaan?
#
# Ishaan is a name for God in the Quran. It means "He who has come" or "The One Who Has Come." The name is derived from the Arabic word "isha," which refers to dawn, and "aan," which means "he came."
#
# In Islamic tradition, Ishaan represents the first messenger sent by Allah to invite people to faith. According to legend, he was sent with a golden tablet containing the names of Allah's messengers.
#
# However, it's important to note that many Muslims do not consider this a literal name but rather an expression of faith. They believe that Ishaan symbolizes the essence of Islam - the call to worship one God (Allah) without any idols or intermediaries between humans and their Creator. This concept emphasizes monotheism and belief in divine unity as central tenets of Islam.
#
# ...

# %%
response = chat_model.invoke("Explain langchain in simple terms")
print(response)
# Out:
# Explain langchain in simple terms
# LangChain is a powerful framework that allows developers to create sophisticated AI models and applications using natural language processing (NLP) techniques. It provides a set of tools and libraries that make it easy to build chatbots, virtual assistants, or any other application that requires understanding human language.
#
# In simpler terms, LangChain acts as a toolkit for creating intelligent machines that can understand and respond to human conversations. It's like having a super-smart robot helper who can interpret what you're saying, remember previous conversations, and provide appropriate responses - all without needing explicit programming instructions. This makes it easier for businesses and individuals to integrate advanced NLP capabilities into their products or services.
