# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaan20072612/LLM-Playbook/blob/main/langchain_hf_pipeline_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -qU --upgrade langchain langchain-community

# %%
from transformers import pipeline
pipe = pipeline("text-generation" , model = "Qwen/Qwen2.5-1.5B-Instruct" , max_length = 512)
# Out:
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
from langchain.llms import HuggingFacePipeline
chat_model = HuggingFacePipeline(pipeline = pipe)
# Out:
# /tmp/ipython-input-1409650531.py:2: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   chat_model = HuggingFacePipeline(pipeline = pipe)

# %%
response = chat_model.invoke("What is the meaning of Ishaan")
print(response)
# Out:
# What is the meaning of Ishaan's name in Hindi and what does it represent?
#
# Ishaan is a popular Indian boy's name that means "the moon" or "night." In Hindu mythology, the moon is considered to be a symbol of purity, wisdom, and knowledge. Therefore, the name Ishaan represents someone who has a deep understanding of the world around them and possesses qualities such as compassion, kindness, and wisdom.
#
# Additionally, the name Ishaan also has a spiritual significance. It is believed that the moon holds a special place in the universe and represents the divine feminine energy. By naming their child after the moon, parents are expressing their belief in the power of this celestial body and its ability to inspire and guide others towards enlightenment.
#
# Overall, the name Ishaan carries both a literal and symbolic meaning, representing not only physical beauty but also inner strength, wisdom, and spirituality.

# %%
response = chat_model.invoke("Explain langchain in simple terms")
print(response)
# Out:
# Explain langchain in simple terms
# LangChain is a tool that helps you create and run complex machine learning models. It's like a recipe book for building AI, where you can mix different ingredients (like algorithms) to make your own unique model.
# Think of it as a super powerful calculator that can handle lots of data at once, but still be easy enough to use for beginners. You just need to tell LangChain what kind of problem you want to solve, and it'll figure out the best way to do it using its many tools.
# So instead of having to write long, complicated code yourself, you can ask LangChain questions or give it instructions, and it will help you build an AI system from scratch - all while keeping things simple so even kids could understand!
